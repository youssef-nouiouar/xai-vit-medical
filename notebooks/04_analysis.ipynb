# %% [markdown]
# # 04 — Analysis & Paper Figures
#
# Aggregate results across 5 models × 7 XAI methods, generate publication figures.
#
# ## Tables to produce
# 1. **Performance** — AUC-ROC, Sens@95Spec per class
# 2. **Faithfulness** — Insertion AUC, Deletion AUC, Faithfulness Score
# 3. **Localization** — Pointing Game, IoU
# 4. **Sanity Checks** — pass/fail per (model, method)
#
# ## Figures
# 1. Saliency comparison grid (5 models × 5 methods on 3 example cases)
# 2. Faithfulness comparison bar chart with bootstrap CI
# 3. Sanity-check pass/fail heatmap
# 4. SAE feature visualization (top features for DeiT vs DINOv2)
# 5. Activation Patching IE heatmap (12×12 layer × component)
