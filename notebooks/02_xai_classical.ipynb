# %% [markdown]
# # 02 — Classical XAI Methods
#
# Run and compare: **Grad-CAM, Integrated Gradients, Attention Rollout, Generic Attention (Chefer 2021), LRP**.
#
# ## Compatibility matrix
#
# |                    | ResNet-50 | ViT-Base | DeiT-Base | DINOv2 | Swin-Base |
# |--------------------|-----------|----------|-----------|--------|-----------|
# | Grad-CAM           | ✓         | ✓        | ✓         | ✓      | ✓         |
# | Integrated Gradients | ✓       | ✓        | ✓         | ✓      | ✓         |
# | Attention Rollout  | —         | ✓        | ✓         | ✓      | ✗         |
# | Generic Attention ⭐ | —       | ✓        | ✓         | ✓      | ⚠         |
# | LRP                | ✓         | ✓        | ✓         | ✓      | ✓         |

# %%
# %load_ext autoreload
# %autoreload 2
import sys; sys.path.insert(0, '..')
