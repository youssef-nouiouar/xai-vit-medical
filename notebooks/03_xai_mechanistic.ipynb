# %% [markdown]
# # 03 — Mechanistic XAI (Contributions thèse)
#
# ## C1 — Sparse Autoencoders (SAE)
# Train SAEs on activations of DeiT-Base and DINOv2-ViT-B at layer `blocks.8.mlp`.
# Compare the % of clinically interpretable features (test of hypothesis H2).
#
# ## C2 — Activation Patching
# Detect shortcuts (dermoscopic ruler) via **Indirect Effect** measurements.
# Decision rule: `IE(artifact_corruption) > 0.3` ⇒ shortcut confirmed.
#
# ## C3 — Circuit Discovery (stretch goal)
# Optional / Phase 2.
